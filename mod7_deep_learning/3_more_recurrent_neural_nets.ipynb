# %% [markdown]
# # Deep Learning: More Recurrent Neural Networks

# %%
# !pip install torchtext==0.6.0
# Out:
# Requirement already satisfied: torchtext==0.6.0 in c:\users\ceojo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.6.0)
# Requirement already satisfied: tqdm in c:\users\ceojo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torchtext==0.6.0) (4.67.1)
# Requirement already satisfied: requests in c:\users\ceojo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torchtext==0.6.0) (2.32.5)
# Requirement already satisfied: torch in c:\users\ceojo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torchtext==0.6.0) (2.9.1)
# Requirement already satisfied: numpy in c:\users\ceojo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torchtext==0.6.0) (2.3.2)
# Requirement already satisfied: six in c:\users\ceojo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torchtext==0.6.0) (1.17.0)
# Requirement already satisfied: sentencepiece in c:\users\ceojo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torchtext==0.6.0) (0.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ceojo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->torchtext==0.6.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ceojo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->torchtext==0.6.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ceojo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->torchtext==0.6.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ceojo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->torchtext==0.6.0) (2025.11.12)
# Requirement already satisfied: filelock in c:\users\ceojo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch->torchtext==0.6.0) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\ceojo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch->torchtext==0.6.0) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\ceojo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch->torchtext==0.6.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\ceojo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch->torchtext==0.6.0) (3.5)
# Requirement already satisfied: jinja2 in c:\users\ceojo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch->torchtext==0.6.0) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\ceojo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch->torchtext==0.6.0) (2025.10.0)
# Requirement already satisfied: colorama in c:\users\ceojo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm->torchtext==0.6.0) (0.4.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\ceojo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sympy>=1.13.3->torch->torchtext==0.6.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ceojo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jinja2->torch->torchtext==0.6.0) (3.0.3)
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: C:\Users\ceojo\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import torch
import torch.nn as nn
import torchtext
from torchtext.data import Field, LabelField, BucketIterator
from torchtext.datasets import SST
from tqdm import tqdm
import matplotlib.pyplot as plt
torch.manual_seed(12)

print(f"Pytorch version: {torch.__version__}")
print(f"Torchtext version: {torchtext.__version__}")
# Out:
# Pytorch version: 2.9.1+cpu
# Torchtext version: 0.6.0

# %% [markdown]
# ### Note: Python must be 3.11.x
#
# If your kernel shows a value > 3.11.x you will need to downgrade. Please email the staff for help

# %%
# DEVICE CONFIGURATION
if torch.backends.mps.is_available():          # Apple Silicon
    device = torch.device("mps")
elif torch.cuda.is_available():                # CUDA GPU
    device = torch.device("cuda")
else:
    device = torch.device("cpu")               # Fallback

print("Using device:", device)
# Out:
# Using device: cpu

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\ceojo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (3.9.2)
# Requirement already satisfied: click in c:\users\ceojo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in c:\users\ceojo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\ceojo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk) (2025.11.3)
# Requirement already satisfied: tqdm in c:\users\ceojo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\ceojo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from click->nltk) (0.4.6)
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: C:\Users\ceojo\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# Define field types
TEXT = Field(tokenize='basic_english', lower=True, include_lengths=True)
LABEL = LabelField(dtype=torch.float)

# Load SST data
train_data, _, test_data = SST.splits(
    TEXT, LABEL, fine_grained=False
)

# %%
# Display size of datasets
print("Train size:", len(train_data))
print("Test size:", len(test_data))
# Out:
# Train size: 8544
# Test size: 2210

# %% [markdown]
# The `.splits` method is splitting up our dataset so that our train and test sets both have representative samples.
#
# The `fine_grained` parameter determines how many categories our data is broken into.
# - if `True`: labels can be {'positive': 0, 'negative': 1, 'neutral': 2, 'very positive': 3, 'very negative': 4}
# - if `False`: labels can be {'positive': 0, 'negative': 1, 'neutral': 2}

# %%
# Build vocabulary
MAX_VOCAB_SIZE = 10000
TEXT.build_vocab(train_data, max_size=MAX_VOCAB_SIZE)
LABEL.build_vocab(train_data)

vocab = TEXT.vocab.stoi
pad_idx = TEXT.vocab.stoi[TEXT.pad_token]

# %% [markdown]
# ### Q: What variable type is `vocab`? What does the `.build_vocab` method do?
# Hint: `.stoi` stand for "string to int"!

# %% [markdown]
# ### A:
# Vocab is a dictionary. The .build_vocab method creates vocab from the training data by counting how often a word appears and making a list of the most common words.

# %%
def decode_dataset(dataset):
    # Reverse label mapping: string -> int
    label_stoi = LABEL.vocab.stoi
    texts = [example.text for example in dataset] 
    labels = [label_stoi[example.label] for example in dataset]
    return texts, labels

train_texts, train_labels = decode_dataset(train_data)
test_texts, test_labels   = decode_dataset(test_data)

# %% [markdown]
# ### Sanity Check 🧠
# Let's check that the decoded dataset makes sense!

# %%
label_map = {idx: word for word, idx in LABEL.vocab.stoi.items()}

# Change i and see what happens!
i = 5

print(" ".join(test_texts[i]))
print(label_map[test_labels[i]])
# Out:
# perhaps no picture ever made has more literally showed that the road to hell is paved with good intentions .
# positive

# %% [markdown]
# ----

# %% [markdown]
# Now let's define a `BucketIterator`:

# %%
BATCH_SIZE = 32
train_iterator, test_iterator = BucketIterator.splits(
    (train_data, test_data),
    batch_size=BATCH_SIZE,
    sort_within_batch=True,
    sort_key=lambda x: len(x.text),
    device=device
)

# %% [markdown]
# Below is a custom classifier:

# %%
# Custom LSTM Classifier
class SimpleLSTM(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, output_dim, pad_idx):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim, padding_idx=pad_idx)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, batch_first=False)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, text, text_lengths):
        # text: [batch_size, seq_len] if batch_first=True
        embedded = self.embedding(text)  # [batch_size, seq_len, emb_dim]

        # Pack padded sequence
        packed_embedded = nn.utils.rnn.pack_padded_sequence(embedded, text_lengths.cpu(), batch_first=False, enforce_sorted=False)
        packed_output, (hidden, cell) = self.lstm(packed_embedded)

        # hidden: [1, batch_size, hidden_dim]  -> take the last hidden state
        return self.fc(hidden.squeeze(0))  # [batch_size, output_dim]

# %% [markdown]
# Here's a helper function so we can vary parameters later:

# %%
# TRAINING LOOP FUNCTION
def run_training_loop(num_epochs, random_state):
    # set random seed
    torch.manual_seed(random_state)

    EMBEDDING_DIM = 100
    HIDDEN_DIM = 256
    OUTPUT_DIM = 1

    # Send model to device
    model = SimpleLSTM(len(vocab), EMBEDDING_DIM, HIDDEN_DIM, OUTPUT_DIM, pad_idx).to(device)
    criterion = nn.BCEWithLogitsLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    # init output vars
    train_losses = []
    train_accs = []

    # train for num_epochs
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0
        epoch_acc = 0

        # Wrap the iterator with tqdm
        for batch in tqdm(train_iterator, desc=f"Epoch {epoch+1}/{num_epochs}"):
            text, text_lengths = batch.text
            labels = batch.label

            text, text_lengths, labels = text.to(device), text_lengths.to(device), labels.to(device)

            optimizer.zero_grad()
            predictions = model(text, text_lengths).squeeze(1)

            # Loss
            loss = criterion(predictions, labels.float())
            loss.backward()
            optimizer.step()

            # Optional: compute accuracy
            preds = torch.round(torch.sigmoid(predictions))
            acc = (preds == labels).float().mean()
            epoch_loss += loss.item()
            epoch_acc += acc.item()
        
        avg_loss = epoch_loss/ len(train_iterator)
        avg_acc = epoch_acc/ len(train_iterator)
        train_losses.append(avg_loss)
        train_accs.append(avg_acc)
        print(f"Loss = {avg_loss:.4f}, Accuracy = {avg_acc:.4f}\n")
    return train_losses, train_accs, model

# %% [markdown]
# And another helper function plot the `train_losses` and `train_accs`:

# %%
def plot_training_performance(train_losses, train_accs, num_epochs, random_state):
    fig = plt.figure(figsize=(8,4), tight_layout=True)
    fig.suptitle(f"Model Training for State {random_state} over {num_epochs} Epochs")

    plt.subplot(1,2,1)
    plt.plot(train_losses, "-o", label="Train Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.grid()
    plt.legend()

    plt.subplot(1,2,2)
    plt.plot(train_accs, "-o", label="Train Accuracy")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy (%)")
    plt.grid()
    plt.legend()
    plt.show()

# %% [markdown]
# Let's train our model!

# %%
NUM_EPOCHS = 15
RANDOM_STATE = 0
train_losses, train_accs, model = run_training_loop(NUM_EPOCHS, RANDOM_STATE)
# Out:
# Epoch 1/15:   0%|          | 0/267 [00:00<?, ?it/s]
# Epoch 1/15: 100%|██████████| 267/267 [00:19<00:00, 13.93it/s]
# Loss = 0.5134, Accuracy = 0.3971
# Epoch 2/15: 100%|██████████| 267/267 [00:17<00:00, 14.94it/s]
# Loss = 0.3471, Accuracy = 0.4651
# Epoch 3/15: 100%|██████████| 267/267 [00:20<00:00, 13.23it/s]
# Loss = -0.3013, Accuracy = 0.5241
# Epoch 4/15: 100%|██████████| 267/267 [00:20<00:00, 13.32it/s]
# Loss = -1.9882, Accuracy = 0.5645
# Epoch 5/15: 100%|██████████| 267/267 [00:21<00:00, 12.60it/s]
# Loss = -7.9312, Accuracy = 0.6066
# Epoch 6/15: 100%|██████████| 267/267 [00:21<00:00, 12.41it/s]
# Loss = -15.8948, Accuracy = 0.6271
# Epoch 7/15: 100%|██████████| 267/267 [00:21<00:00, 12.65it/s]
# Loss = -27.7586, Accuracy = 0.6564
# Epoch 8/15: 100%|██████████| 267/267 [00:20<00:00, 12.85it/s]
# Loss = -43.0040, Accuracy = 0.6842
# Epoch 9/15: 100%|██████████| 267/267 [00:21<00:00, 12.49it/s]
# Loss = -53.9502, Accuracy = 0.6856
# Epoch 10/15: 100%|██████████| 267/267 [00:23<00:00, 11.22it/s]
# Loss = -67.0001, Accuracy = 0.6971
# Epoch 11/15: 100%|██████████| 267/267 [00:24<00:00, 10.80it/s]
# Loss = -81.9135, Accuracy = 0.7027
# Epoch 12/15: 100%|██████████| 267/267 [00:23<00:00, 11.54it/s]
# Loss = -96.8354, Accuracy = 0.7159
# Epoch 13/15: 100%|██████████| 267/267 [00:21<00:00, 12.63it/s]
# Loss = -110.9551, Accuracy = 0.7226
# Epoch 14/15: 100%|██████████| 267/267 [00:22<00:00, 12.12it/s]
# Loss = -122.0047, Accuracy = 0.7118
# Epoch 15/15: 100%|██████████| 267/267 [00:21<00:00, 12.26it/s]
# Loss = -137.5454, Accuracy = 0.7295

# %%
plot_training_performance(train_losses, train_accs, NUM_EPOCHS, RANDOM_STATE)

# %% [markdown]
# ### Q: Try changing the value of `NUM_EPOCHS`. What happens to the train loss and accuracy plots? What does this tell us about the optimal number of training epochs?

# %% [markdown]
# ### A:
# Until a certain number of epochs, the training loss decreases and the accuracy increases. However, after a certain number of epochs, the training loss keeps decreasing but the accuracy increases by only a little bit or even decreases. This shows that the optimal number of epochs is just before the accuracy starts decreasing due to overfitting.

# %% [markdown]
# ### Q: Try changing the value of `RANDOM_STATE`. What happens to the train loss and accuracy plots? What does this tell us about the impact of the initial guess (i.e. epoch 0)?

# %% [markdown]
# ### A:
# Changing the random state changes te shape of the train loss and accuracy plots a little bit, but it ends with a similar result. THis shows thar the initial guess can change the shape of the plot, but the resulting performance will be similar.

# %% [markdown]
# ----

# %% [markdown]
# ## Performance on the Test Set

# %% [markdown]
# Here's a helper function to run our model on the test data:

# %%
# Evaluate on test set
def run_evaluation_test():
    model.eval()
    test_loss, test_acc, = 0,0

    with torch.no_grad():
        for batch in test_iterator:
            text, text_lengths = batch.text
            labels = batch.label

            text = text.to(device)
            text_lengths = text_lengths.to(device)
            labels = labels.to(device)

            criterion = nn.BCEWithLogitsLoss()
            predictions = model(text, text_lengths).squeeze(1)
            loss = criterion(predictions, labels.float())

            preds = torch.round(torch.sigmoid(predictions))
            acc = (preds == labels).float().mean()

            test_loss += loss.item()
            test_acc += acc.item()

    return print(f"Test Accuracy: {100 * test_acc / len(test_iterator):.2f}%")

# %% [markdown]
# Finally, let's check that our model can generalize by processing the test data:

# %%
run_evaluation_test()
# Out:
# Test Accuracy: 56.47%

# %% [markdown]
# ----
# ## Further Exploration 🔎

# %% [markdown]
# ### Q: What happens to the **test** accuracy as `NUM_EPOCHS` is changed? What does this tell us about our neural network?
# Note: remember to re-train your model before running on the test set!

# %% [markdown]
# ### A:
# As the number of epochs increase, the test accuracy increases, but only to a ceratin number of epochs before the model accuracy stays constant or even decreases. This shows that too many epochs doesn't always mean better accuracy.

# %% [markdown]
# ### Q: What happens to the **test** accuracy as `RANDOM_STATE` is changed? What does this tell us about our neural network?
# Note: remember to re-train your model before running on the test set!

# %% [markdown]
# ### A:
# Changing the random state can change the test accuracy slightly, but it converges to a certain range of accuracy after training.

# %% [markdown]
# ### Q: What happens to your results if you set `find_grained=True`?
# Try to predict first and then test your hypothesis by changing the value and re-running the notebook!

# %% [markdown]
# ### A:
# Setting the find_grained-True changes the results slightly and it might make the results more accurate.
